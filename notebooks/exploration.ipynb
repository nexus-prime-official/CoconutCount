# %%
# !pip list
# Out:
# Package            Version
# ------------------ -----------
# annotated-types    0.7.0
# asttokens          2.4.1
# blis               0.7.11
# catalogue          2.0.10
# certifi            2024.6.2
# charset-normalizer 3.3.2
# click              8.1.7
# cloudpathlib       0.18.1
# colorama           0.4.6
# comm               0.2.2
# confection         0.1.5
# contourpy          1.2.1
# cycler             0.12.1
# cymem              2.0.8
# debugpy            1.8.1
# decorator          5.1.1
# executing          2.0.1
# fastai             2.7.15
# fastcore           1.5.46
# fastdownload       0.0.7
# fastprogress       1.0.3
# filelock           3.15.3
# fonttools          4.53.0
# fsspec             2024.6.0
# idna               3.7
# intel-openmp       2021.4.0
# ipykernel          6.29.4
# ipython            8.25.0
# jedi               0.19.1
# Jinja2             3.1.4
# joblib             1.4.2
# jupyter_client     8.6.2
# jupyter_core       5.7.2
# kiwisolver         1.4.5
# ...
